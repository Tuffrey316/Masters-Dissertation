# %%
import fastf1
import pandas as pd

test_data = fastf1.get_session(2024, "British", "R")
test_data.load(telemetry=True)
test_data
# Out:
# core           INFO 	Loading data for British Grand Prix - Race [v3.3.9]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
test_data.laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 0   0 days 00:59:51.833000    HAM           44                    NaT
# 1   0 days 01:01:23.253000    HAM           44 0 days 00:01:31.420000
# 2   0 days 01:02:54.969000    HAM           44 0 days 00:01:31.716000
# 3   0 days 01:04:26.957000    HAM           44 0 days 00:01:31.988000
# 4   0 days 01:05:58.634000    HAM           44 0 days 00:01:31.677000
# ..                     ...    ...          ...                    ...
# 956 0 days 01:45:56.268000    RUS           63 0 days 00:01:41.237000
# 957 0 days 01:47:38.170000    RUS           63 0 days 00:01:41.902000
# 958 0 days 01:49:21.255000    RUS           63 0 days 00:01:43.085000
# 959 0 days 01:51:07.476000    RUS           63 0 days 00:01:46.221000
# 960 0 days 00:59:51.010000    GAS           10                    NaT
#
#      LapNumber  Stint PitOutTime              PitInTime  \
# 0          1.0    1.0        NaT                    NaT
# ...

# %%
test_data.laps['Driver']
# Out:
# 0      HAM
# 1      HAM
# 2      HAM
# 3      HAM
# 4      HAM
#       ...
# 956    RUS
# 957    RUS
# 958    RUS
# 959    RUS
# 960    GAS
# Name: Driver, Length: 961, dtype: object

# %%
drivers = test_data.laps['Driver'].unique().tolist()
drivers
# Out:
# ['HAM',
#  'VER',
#  'NOR',
#  'PIA',
#  'SAI',
#  'HUL',
#  'STR',
#  'ALO',
#  'ALB',
#  'TSU',
#  'SAR',
#  'MAG',
#  'RIC',
#  'LEC',
#  'BOT',
#  'OCO',
#  'PER',
#  'ZHO',
#  'RUS',
#  'GAS']

# %%
driver = 'HAM'
for lap in test_data.laps.pick_driver(driver):
    lap_tel = lap.get_telemetry()
    if i == 0:
        telemetry = pd.DataFrame(lap_tel)
        i+=1
    else:
        telemetry.concat(lap_tel)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 3
#       1 driver = 'HAM'
#       2 for lap in test_data.laps.pick_driver(driver):
# ----> 3     lap_tel = lap.get_telemetry()
#       4     if i == 0:
#       5         telemetry = pd.DataFrame(lap_tel)
#
# AttributeError: 'str' object has no attribute 'get_telemetry'

# %%
ham_laps = test_data.laps.pick_driver('HAM').get_telemetry()
ham_laps['Driver']='HAM'
ham_laps
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
#                          Date            SessionTime DriverAhead  \
# 2     2024-07-07 14:03:12.541 0 days 00:58:15.512000
# 3     2024-07-07 14:03:12.660 0 days 00:58:15.631000
# 4     2024-07-07 14:03:12.831 0 days 00:58:15.802000
# 5     2024-07-07 14:03:12.931 0 days 00:58:15.902000
# 6     2024-07-07 14:03:12.980 0 days 00:58:15.951000          14
# ...                       ...                    ...         ...
# 37776 2024-07-07 15:25:39.472 0 days 02:20:42.443000           1
# 37777 2024-07-07 15:25:39.476 0 days 02:20:42.447000           1
# 37778 2024-07-07 15:25:39.752 0 days 02:20:42.723000           1
# 37779 2024-07-07 15:25:39.836 0 days 02:20:42.807000           1
# ...

# %%
i=0
for driver in drivers:
    driver_laps = test_data.laps.pick_driver(driver).get_telemetry()
    driver_laps['Driver']=driver
    if i == 0:
        telemetry = pd.DataFrame(driver_laps)
        i+=1
    else:
        data = [telemetry,driver_laps]
        telemetry = pd.concat(data)
        i+=1
telemetry.to_csv('test_telemetry.csv')
# Out:
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Y' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'Z' while merging telemetry.
# core        WARNING 	Failed to preserve data type for column 'X' while merging telemetry.
# ...
